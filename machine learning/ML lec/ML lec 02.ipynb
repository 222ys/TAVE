# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# * Linear Hypothesis : H(x) = Wx + b
# * Cost(Loss) function : {H(x) - y}^2
# * cost(W,b) = { (예측값-정답값)들의 제곱의 합 } / (데이터 개수)

# %% [markdown]
# * Goal : minimize cost(W,b) 하는 W, b 찾는 것

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\crsunnbi\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Linear Regression 실습

# %% [markdown]
# ### Build Graph using TF operations

# %% [markdown]
# H(x) = Wx + b

# %%
# X and Y data
x_train = [1,2,3]
y_train = [1,2,3]

# 가중치, 편향 선언
W = tf.Variable(tf.random_normal([1]), name='weight') # [1]은 shape 정의
b = tf.Variable(tf.random_normal([1]), name='bias')

# 가설 노드 선언
hypothesis = x_train * W + b

# %% [markdown]
# cost(W,b) = { (예측값-정답값)들의 제곱의 합 } / (데이터 개수)

# %%
# cost(Loss) function 선언
cost = tf.reduce_mean(tf.square(hypothesis - y_train))
# tf.reduce_mean(t) : t에 들어가는 값들의 평균을 내주는 함수

# %% [markdown]
# GradientDescent : minimize cost

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %% [markdown]
# ### Run graph and get results

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer()) # 노드 초기화 필수

for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 38.10446 [-1.7054576] [-0.3531798]
# 20 0.4089131 [0.47777668] [0.5678948]
# 40 0.0613165 [0.6980985] [0.6273294]
# 60 0.05287735 [0.7309287] [0.6060478]
# 80 0.047998577 [0.74534917] [0.57834667]
# 100 0.04359287 [0.7574858] [0.551241]
# 120 0.03959174 [0.76889914] [0.52534175]
# 140 0.03595786 [0.77976155] [0.5006534]
# 160 0.032657497 [0.7901121] [0.47712457]
# 180 0.029660067 [0.7999761] [0.45470148]
# 200 0.026937753 [0.8093764] [0.43333218]
# 220 0.024465306 [0.818335] [0.4129672]
# 240 0.022219772 [0.8268726] [0.3935592]
# 260 0.02018035 [0.8350089] [0.3750634]
# 280 0.018328115 [0.84276295] [0.35743675]
# 300 0.01664588 [0.85015255] [0.34063852]
# 320 0.01511807 [0.8571948] [0.32462975]
# 340 0.013730465 [0.86390615] [0.30937338]
# 360 0.0124702295 [0.870302] [0.29483402]
# 380 0.011325666 [0.8763973] [0.28097785]
# 400 0.010286155 [0.8822062] [0.26777303]
# 420 0.0093420595 [0.887742] [0.25518873]
# 440 0.008484605 [0.89301777] [0.24319582]
# ...

# %% [markdown]
# # Linear Regression 실습 w. Placeholders

# %%
X = tf.placeholder(tf.float32, shape=[None]) # [None] : 1차원 벡터
Y = tf.placeholder(tf.float32, shape=[None])
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')
hypothesis = X * W + b 

cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], \
                                         feed_dict={X: [1,2,3,4,5],\
                                                    Y:[2.1,3.1,4.1,5.1,6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 1.6703352 [1.8377023] [-1.2885588]
# 20 0.9480246 [1.6307298] [-1.1742628]
# 40 0.8279067 [1.5887357] [-1.02551]
# 60 0.7230169 [1.5501758] [-0.8863093]
# 80 0.63141614 [1.5141444] [-0.7562244]
# 100 0.55142033 [1.4804727] [-0.63465875]
# 120 0.48155937 [1.4490061] [-0.5210546]
# 140 0.42054957 [1.4196004] [-0.41489044]
# 160 0.3672691 [1.3921204] [-0.31567913]
# 180 0.32073885 [1.3664402] [-0.2229652]
# 200 0.28010353 [1.3424417] [-0.1363231]
# 220 0.24461651 [1.3200148] [-0.05535532]
# 240 0.21362543 [1.2990569] [0.02030982]
# 260 0.1865607 [1.2794714] [0.09101962]
# 280 0.16292477 [1.2611686] [0.15709856]
# 300 0.1422835 [1.2440645] [0.2188499]
# 320 0.12425722 [1.2280804] [0.27655706]
# 340 0.108514726 [1.2131433] [0.33048496]
# 360 0.09476679 [1.1991844] [0.38088116]
# 380 0.08276054 [1.1861397] [0.42797676]
# 400 0.07227536 [1.1739491] [0.4719881]
# 420 0.06311866 [1.1625571] [0.5131171]
# 440 0.05512201 [1.1519111] [0.55155236]
# 460 0.04813846 [1.1419624] [0.5874707]
# ...

# %% [markdown]
# * Test our model

# %%
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [6.1010723]
# [3.599144]
# [2.5983725 4.599915 ]
